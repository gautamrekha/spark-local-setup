# %%
from pyspark.sql import SparkSession

# 1️⃣ Start Spark session
spark = SparkSession.builder.appName("QuickTest").getOrCreate()

# 2️⃣ Simple DataFrame
df = spark.createDataFrame([("Alice", 34), ("Bob", 45)], ["name", "age"])
df.show()

# 3️⃣ Stop Spark session
spark.stop()
